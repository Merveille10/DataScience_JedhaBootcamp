# %%
import pandas as pd
path = "c:\\Users\\ADMIN\\Downloads\\introduction_pandas"
data = pd.read_csv(path + "/covid-19.csv")
data.head()
# Out:
#    Unnamed: 0     dateRep  day  month  year  cases  deaths  \
# 0        1257  2020-04-23   23      4  2020    933     264
# 1        1258  2020-04-22   22      4  2020    973     170
# 2        1259  2020-04-21   21      4  2020   1487     145
# 3        1260  2020-04-20   20      4  2020   1313     230
# 4        1261  2020-04-19   19      4  2020   1045     290
#
#   countriesAndTerritories geoId countryterritoryCode  popData2018 continentExp
# 0                 Belgium    BE                  BEL   11422068.0       Europe
# 1                 Belgium    BE                  BEL   11422068.0       Europe
# 2                 Belgium    BE                  BEL   11422068.0       Europe
# 3                 Belgium    BE                  BEL   11422068.0       Europe
# 4                 Belgium    BE                  BEL   11422068.0       Europe

# %%
data = data.iloc[:, 1:]
data.head()
# Out:
#       dateRep  day  month  year  cases  deaths countriesAndTerritories geoId  \
# 0  2020-04-23   23      4  2020    933     264                 Belgium    BE
# 1  2020-04-22   22      4  2020    973     170                 Belgium    BE
# 2  2020-04-21   21      4  2020   1487     145                 Belgium    BE
# 3  2020-04-20   20      4  2020   1313     230                 Belgium    BE
# 4  2020-04-19   19      4  2020   1045     290                 Belgium    BE
#
#   countryterritoryCode  popData2018 continentExp
# 0                  BEL   11422068.0       Europe
# 1                  BEL   11422068.0       Europe
# 2                  BEL   11422068.0       Europe
# 3                  BEL   11422068.0       Europe
# 4                  BEL   11422068.0       Europe

# %%
mask = data["geoId"] == "US"
us_data = data[mask]
us_data.head()
# Out:
#         dateRep  day  month  year  cases  deaths   countriesAndTerritories  \
# 575  2020-04-23   23      4  2020  17588    1721  United_States_of_America
# 576  2020-04-22   22      4  2020  37289    2524  United_States_of_America
# 577  2020-04-21   21      4  2020  28065    1857  United_States_of_America
# 578  2020-04-20   20      4  2020  24601    1772  United_States_of_America
# 579  2020-04-19   19      4  2020  32922    1856  United_States_of_America
#
#     geoId countryterritoryCode  popData2018 continentExp
# 575    US                  USA  327167434.0      America
# 576    US                  USA  327167434.0      America
# 577    US                  USA  327167434.0      America
# 578    US                  USA  327167434.0      America
# 579    US                  USA  327167434.0      America

# %%
us_data = us_data.reset_index(drop=True)
us_data.head()
# Out:
#       dateRep  day  month  year  cases  deaths   countriesAndTerritories  \
# 0  2020-04-23   23      4  2020  17588    1721  United_States_of_America
# 1  2020-04-22   22      4  2020  37289    2524  United_States_of_America
# 2  2020-04-21   21      4  2020  28065    1857  United_States_of_America
# 3  2020-04-20   20      4  2020  24601    1772  United_States_of_America
# 4  2020-04-19   19      4  2020  32922    1856  United_States_of_America
#
#   geoId countryterritoryCode  popData2018 continentExp
# 0    US                  USA  327167434.0      America
# 1    US                  USA  327167434.0      America
# 2    US                  USA  327167434.0      America
# 3    US                  USA  327167434.0      America
# 4    US                  USA  327167434.0      America

# %%
total_rows = len(us_data)
print(total_rows)
# Out:
# 115

# %%
us_data["cumulative_cases"] = 0
us_data.head()
# Out:
#       dateRep  day  month  year  cases  deaths   countriesAndTerritories  \
# 0  2020-04-23   23      4  2020  17588    1721  United_States_of_America
# 1  2020-04-22   22      4  2020  37289    2524  United_States_of_America
# 2  2020-04-21   21      4  2020  28065    1857  United_States_of_America
# 3  2020-04-20   20      4  2020  24601    1772  United_States_of_America
# 4  2020-04-19   19      4  2020  32922    1856  United_States_of_America
#
#   geoId countryterritoryCode  popData2018 continentExp  cumulative_cases
# 0    US                  USA  327167434.0      America                 0
# 1    US                  USA  327167434.0      America                 0
# 2    US                  USA  327167434.0      America                 0
# 3    US                  USA  327167434.0      America                 0
# 4    US                  USA  327167434.0      America                 0

# %%
for i in range(total_rows-2, -1, -1):
    us_data.loc[i, "cumulative_cases"] = us_data.loc[i, "cases"] + us_data.loc[i + 1, "cumulative_cases"]

# %%
us_data.head()
# Out:
#       dateRep  day  month  year  cases  deaths   countriesAndTerritories  \
# 0  2020-04-23   23      4  2020  17588    1721  United_States_of_America
# 1  2020-04-22   22      4  2020  37289    2524  United_States_of_America
# 2  2020-04-21   21      4  2020  28065    1857  United_States_of_America
# 3  2020-04-20   20      4  2020  24601    1772  United_States_of_America
# 4  2020-04-19   19      4  2020  32922    1856  United_States_of_America
#
#   geoId countryterritoryCode  popData2018 continentExp  cumulative_cases
# 0    US                  USA  327167434.0      America            842629
# 1    US                  USA  327167434.0      America            825041
# 2    US                  USA  327167434.0      America            787752
# 3    US                  USA  327167434.0      America            759687
# 4    US                  USA  327167434.0      America            735086

# %%
us_data["cases_per_day"] = 0
us_data.head()
# Out:
#       dateRep  day  month  year  cases  deaths   countriesAndTerritories  \
# 0  2020-04-23   23      4  2020  17588    1721  United_States_of_America
# 1  2020-04-22   22      4  2020  37289    2524  United_States_of_America
# 2  2020-04-21   21      4  2020  28065    1857  United_States_of_America
# 3  2020-04-20   20      4  2020  24601    1772  United_States_of_America
# 4  2020-04-19   19      4  2020  32922    1856  United_States_of_America
#
#   geoId countryterritoryCode  popData2018 continentExp  cumulative_cases  \
# 0    US                  USA  327167434.0      America            842629
# 1    US                  USA  327167434.0      America            825041
# 2    US                  USA  327167434.0      America            787752
# 3    US                  USA  327167434.0      America            759687
# 4    US                  USA  327167434.0      America            735086
#
#    cases_per_day
# 0              0
# 1              0
# 2              0
# ...

# %%
for i in range(0, total_rows-1, 1):
    us_data.loc[i, "cases_per_day"] = us_data.loc[i, "cumulative_cases"] - us_data.loc[i+1, "cumulative_cases"]

# %%
us_data.head()
# Out:
#       dateRep  day  month  year  cases  deaths   countriesAndTerritories  \
# 0  2020-04-23   23      4  2020  17588    1721  United_States_of_America
# 1  2020-04-22   22      4  2020  37289    2524  United_States_of_America
# 2  2020-04-21   21      4  2020  28065    1857  United_States_of_America
# 3  2020-04-20   20      4  2020  24601    1772  United_States_of_America
# 4  2020-04-19   19      4  2020  32922    1856  United_States_of_America
#
#   geoId countryterritoryCode  popData2018 continentExp  cumulative_cases  \
# 0    US                  USA  327167434.0      America            842629
# 1    US                  USA  327167434.0      America            825041
# 2    US                  USA  327167434.0      America            787752
# 3    US                  USA  327167434.0      America            759687
# 4    US                  USA  327167434.0      America            735086
#
#    cases_per_day
# 0          17588
# 1          37289
# 2          28065
# ...

# %%
us_data["growth_ratio"] = 0
us_data.head()
# Out:
#       dateRep  day  month  year  cases  deaths   countriesAndTerritories  \
# 0  2020-04-23   23      4  2020  17588    1721  United_States_of_America
# 1  2020-04-22   22      4  2020  37289    2524  United_States_of_America
# 2  2020-04-21   21      4  2020  28065    1857  United_States_of_America
# 3  2020-04-20   20      4  2020  24601    1772  United_States_of_America
# 4  2020-04-19   19      4  2020  32922    1856  United_States_of_America
#
#   geoId countryterritoryCode  popData2018 continentExp  cumulative_cases  \
# 0    US                  USA  327167434.0      America            842629
# 1    US                  USA  327167434.0      America            825041
# 2    US                  USA  327167434.0      America            787752
# 3    US                  USA  327167434.0      America            759687
# 4    US                  USA  327167434.0      America            735086
#
#    cases_per_day  growth_ratio
# 0          17588             0
# ...

# %%
for i in range(0, total_rows-1, 1):
    us_data.loc[i, "growth_ratio"] = us_data.loc[i, "cases_per_day"] / us_data.loc[i+1, "cases_per_day"]
us_data.head()
# Out:
# C:\Users\ADMIN\AppData\Local\Temp\ipykernel_10472\4100100318.py:2: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '0.471667247713803' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   us_data.loc[i, "growth_ratio"] = us_data.loc[i, "cases_per_day"] / us_data.loc[i+1, "cases_per_day"]
# C:\Users\ADMIN\AppData\Local\Temp\ipykernel_10472\4100100318.py:2: RuntimeWarning: divide by zero encountered in scalar divide
#   us_data.loc[i, "growth_ratio"] = us_data.loc[i, "cases_per_day"] / us_data.loc[i+1, "cases_per_day"]
# C:\Users\ADMIN\AppData\Local\Temp\ipykernel_10472\4100100318.py:2: RuntimeWarning: divide by zero encountered in scalar divide
#   us_data.loc[i, "growth_ratio"] = us_data.loc[i, "cases_per_day"] / us_data.loc[i+1, "cases_per_day"]
# ...

# %%
pip install matplotlib
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 23.2.1 -> 24.0
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
us_data.plot.line(x="dateRep", y="cumulative_cases")
# Out:
# <Axes: xlabel='dateRep'>

# %%
us_data = us_data.sort_values("dateRep")
us_data.head()
# Out:
#         dateRep  day  month  year  cases  deaths   countriesAndTerritories  \
# 114  2019-12-31   31     12  2019      0       0  United_States_of_America
# 113  2020-01-01    1      1  2020      0       0  United_States_of_America
# 112  2020-01-02    2      1  2020      0       0  United_States_of_America
# 111  2020-01-03    3      1  2020      0       0  United_States_of_America
# 110  2020-01-04    4      1  2020      0       0  United_States_of_America
#
#     geoId countryterritoryCode  popData2018 continentExp  cumulative_cases  \
# 114    US                  USA  327167434.0      America                 0
# 113    US                  USA  327167434.0      America                 0
# 112    US                  USA  327167434.0      America                 0
# 111    US                  USA  327167434.0      America                 0
# 110    US                  USA  327167434.0      America                 0
#
#      cases_per_day  growth_ratio
# ...

# %%
us_data.plot.line(x="dateRep", y="cumulative_cases")
# Out:
# <Axes: xlabel='dateRep'>

# %%
us_data.plot.line(x="dateRep", y="growth_ratio")
# Out:
# <Axes: xlabel='dateRep'>

# %%
ratio_mask = us_data["growth_ratio"] < 7.5
us_data = us_data[ratio_mask]
us_data.head()
# Out:
#         dateRep  day  month  year  cases  deaths   countriesAndTerritories  \
# 114  2019-12-31   31     12  2019      0       0  United_States_of_America
# 92   2020-01-22   22      1  2020      0       0  United_States_of_America
# 88   2020-01-26   26      1  2020      0       0  United_States_of_America
# 86   2020-01-28   28      1  2020      0       0  United_States_of_America
# 82   2020-02-01    1      2  2020      1       0  United_States_of_America
#
#     geoId countryterritoryCode  popData2018 continentExp  cumulative_cases  \
# 114    US                  USA  327167434.0      America                 0
# 92     US                  USA  327167434.0      America                 1
# 88     US                  USA  327167434.0      America                 2
# 86     US                  USA  327167434.0      America                 5
# 82     US                  USA  327167434.0      America                 7
#
#      cases_per_day  growth_ratio
# ...

# %%
us_data.plot.line(x="dateRep", y="growth_ratio", figsize=(10,5), grid=True)
# Out:
# <Axes: xlabel='dateRep'>

# %%
us_data.to_csv("us_data.csv")
