# %%
# !pwd
# Out:
# 'pwd' n'est pas reconnu en tant que commande interne
# ou externe, un programme ex�cutable ou un fichier de commandes.

# %%
pwd
# Out:
# 'c:\\Users\\ADMIN\\Downloads\\introduction_pandas'

# %%
path = "c:\\Users\\ADMIN\\Downloads\\introduction_pandas"

# %%
pip install pandas
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 23.2.1 -> 24.0
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import pandas as pd

# %%
df = pd.read_csv(path + "/covid-19.csv")

# %%
print(df.info())
print(df.shape)
df.head(10)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 690 entries, 0 to 689
# Data columns (total 12 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Unnamed: 0               690 non-null    int64
#  1   dateRep                  690 non-null    object
#  2   day                      690 non-null    int64
#  3   month                    690 non-null    int64
#  4   year                     690 non-null    int64
#  5   cases                    690 non-null    int64
#  6   deaths                   690 non-null    int64
#  7   countriesAndTerritories  690 non-null    object
#  8   geoId                    690 non-null    object
#  9   countryterritoryCode     690 non-null    object
#  10  popData2018              690 non-null    float64
#  11  continentExp             690 non-null    object
# dtypes: float64(1), int64(6), object(5)
# memory usage: 64.8+ KB
# None
# (690, 12)
# ...

# %%
df.describe()
# Out:
#          Unnamed: 0         day       month         year         cases  \
# count    690.000000  690.000000  690.000000   690.000000    690.000000
# mean    7785.666667   15.078261    2.486957  2019.991304   2221.565217
# std     4174.782873    8.616804    1.405144     0.092912   5717.666660
# min     1257.000000    1.000000    1.000000  2019.000000      0.000000
# 25%     4200.250000    8.000000    1.000000  2020.000000      0.000000
# 50%     8482.500000   15.000000    2.000000  2020.000000      3.000000
# 75%    12040.750000   22.000000    3.000000  2020.000000   1870.000000
# max    12251.000000   31.000000   12.000000  2020.000000  37289.000000
#
#             deaths   popData2018
# count   690.000000  6.900000e+02
# mean    201.866667  9.653679e+07
# std     446.431768  1.049538e+08
# min       0.000000  1.142207e+07
# 25%       0.000000  4.672375e+07
# 50%       0.000000  6.346014e+07
# 75%     202.750000  6.698724e+07
# max    4928.000000  3.271674e+08

# %%
df.count()
# Out:
# Unnamed: 0                 690
# dateRep                    690
# day                        690
# month                      690
# year                       690
# cases                      690
# deaths                     690
# countriesAndTerritories    690
# geoId                      690
# countryterritoryCode       690
# popData2018                690
# continentExp               690
# dtype: int64

# %%
df.max()
# Out:
# Unnamed: 0                                    12251
# dateRep                                  2020-04-23
# day                                              31
# month                                            12
# year                                           2020
# cases                                         37289
# deaths                                         4928
# countriesAndTerritories    United_States_of_America
# geoId                                            US
# countryterritoryCode                            USA
# popData2018                             327167434.0
# continentExp                                 Europe
# dtype: object

# %%
df = df.iloc[:, 1:]
df.head()
# Out:
#       dateRep  day  month  year  cases  deaths countriesAndTerritories geoId  \
# 0  2020-04-23   23      4  2020    933     264                 Belgium    BE
# 1  2020-04-22   22      4  2020    973     170                 Belgium    BE
# 2  2020-04-21   21      4  2020   1487     145                 Belgium    BE
# 3  2020-04-20   20      4  2020   1313     230                 Belgium    BE
# 4  2020-04-19   19      4  2020   1045     290                 Belgium    BE
#
#   countryterritoryCode  popData2018 continentExp
# 0                  BEL   11422068.0       Europe
# 1                  BEL   11422068.0       Europe
# 2                  BEL   11422068.0       Europe
# 3                  BEL   11422068.0       Europe
# 4                  BEL   11422068.0       Europe

# %%
us_mask = df["geoId"] =="US"
df[mask]
# Out:
#         dateRep  day  month  year  cases  deaths countriesAndTerritories  \
# 0    2020-04-23   23      4  2020    933     264                 Belgium
# 1    2020-04-22   22      4  2020    973     170                 Belgium
# 2    2020-04-21   21      4  2020   1487     145                 Belgium
# 3    2020-04-20   20      4  2020   1313     230                 Belgium
# 4    2020-04-19   19      4  2020   1045     290                 Belgium
# ..          ...  ...    ...   ...    ...     ...                     ...
# 110  2020-01-04    4      1  2020      0       0                 Belgium
# 111  2020-01-03    3      1  2020      0       0                 Belgium
# 112  2020-01-02    2      1  2020      0       0                 Belgium
# 113  2020-01-01    1      1  2020      0       0                 Belgium
# 114  2019-12-31   31     12  2019      0       0                 Belgium
#
#     geoId countryterritoryCode  popData2018 continentExp
# ...
